# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_regression as mr
x,y=mr(n_samples=1000,n_features=5, noise=0)
print(x.shape)
print(y.shape)

ax=plt.subplots(5,1)
for i in range(5):
    plt.subplot(231+i)
    plt.scatter(x[:,i],y,color='red')
# Out:
# (1000, 5)
# (1000,)
# C:\Users\sonuk\AppData\Local\Temp\ipykernel_14312\4055703653.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(231+i)

# %%
import numpy as np

x=np.arange(1,10,0.1)
m=3
c=2
y=m*x+c
plt.plot(x,y)
plt.show()
